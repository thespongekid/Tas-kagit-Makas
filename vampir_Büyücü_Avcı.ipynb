# %% [markdown]
# <a href="https://colab.research.google.com/github/thespongekid/Tas-kagit-Makas/blob/main/vampir_B%C3%BCy%C3%BCc%C3%BC_Avc%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def Vampir_Büyücü_Avcı():

  print("--------GİRİŞ--------\n"

"Bir zamanlar, uzak bir köyde tam 3 tür varlık yaşarmış.\n"

"--------SEÇİLEBİLİR KAHRAMANLAR--------\n"

"Bu kahramanlardan biri AVCI,\n "
"biri VAMPİR bir diğeri ise BÜYÜCÜ'ymüş.\n"

"--------KAHRAMAN OYNANIŞLARI--------\n"

"Bu kahramanlardan VAMPİR, AVCI'dan korkar\n"
"BÜYÜCÜ'yü ise bir güzel ısırırmış.\n"

"BÜYÜCÜ ise VAMPİR'den korkar, AVCI'yı ise\n"
"yakalar mahzenine atarmış.\n"

"Pek hala AVCI ise BÜYÜCÜ'den korkar, VAMPİR'i\n"
"bir güzel avlarmış.\n"

"--------OYUN KURALLARI ÖZET--------\n"

"Vampir; Büyücü'yü yener, Avcı'ya yenilir.\n"

"Büyücü; Avcı'yı yener, Vampir'e yenilir.\n"

"Avcı; Vampir'i yener, Büyücü'ye yenilir.\n"

"-Oyun içinde 2 turu kazanan oyuncu galibiyeti elde eder."

"Artık oynanışı öğrendiğine göre benimle bir oyun oynamak istersin gibi duruyor.\n Şimdi şöyle yapıyoruz: Eğer sen 2 tur kazanırsan köyün kurtulur, Eğer ben kazanırsam ise neler olacağını sen düşün hahaha!")
  import random
  value1 = 0
  value2 = 0
  while True:
      seçim1 = input("Hadi bakalım şimdi aşağıdaki seçeneklerden birini seç!\n -Vampir\n -Büyücü\n -Avcı\n -Çıkış\n")
      seçimler = ["Vampir","Avcı","Büyücü"]
      seçim2 = random.choice(seçimler)

      if seçim1 == "Vampir":
        print("Sen:" , seçim1 , "seçtin" , "\n" ,"Ben:", seçim2 , "seçtim", "\n" )
        if seçim2 == "Büyücü":
                value1 += 1
                print("Aferin beni yendin...")

        elif seçim2 == "Vampir":
          print("Ne bu berabere mi şimdi?!")

        elif seçim2 == "Avcı":
          value2 += 1
          print("Ben kazandım işte!")


      elif seçim1 == "Avcı":
        print("Sen:" , seçim1 , "seçtin" , "\n" ,"Ben:", seçim2 , "seçtim", "\n" )
        if seçim2 == "Büyücü":
            value2 += 1
            print("Ben kazandım işte!")


        elif seçim2 == "Vampir":
          value1 += 1
          print("Aferin beni yendin...")

        elif seçim2 == "Avcı":
          print("Ne bu berabere mi şimdi?!\n")

      elif seçim1 == "Büyücü":
        print("Sen:" , seçim1 , "seçtin" , "\n", "Ben:", seçim2 , "seçtim", "\n" )

        if seçim2 == "Büyücü":
          print("Ne bu berabere mi şimdi?!")

        elif seçim2 == "Vampir":
          value2 += 1
          print("Ben kazandım işte!")

        elif seçim2 == "Avcı":
          value1 += 1
          print("Aferin beni yendin...")

      elif seçim1 == "Çıkış":
        print("Köyünü terk edecek kadar korkaksın demek ki...Ne diyebilirim ki, hazır olduğunda çağır.")
        break

      else:
        print("Lütfen geçerli bir değer giriniz")

      print("Senin skorun:" + str(value1) + "\n" + "Benim skorum:" + str(value2) + "\n")

      if value1 == 2 and value2 == 1:
        print("Aferin, köyünü kurtardın!\n")
        cevap = input("Çok yorulmadıysan bir el daha oynamak ister misin? -Evet\n -Hayır\n")

        if cevap == "Hayır":
          print("Ben de oynamak istemiyordum zaten, iyi oyundu, görüşürüz!")
          break
        elif cevap == "Evet":
          value1 -= 2
          value2 -= 1
          print("Harika ben de bir oyun daha oynamak isterim.")
          continue
        else:
          print("Lütfen geçerli bir değer giriniz!")
          continue

      if value1 == 2 and value2 == 0:
        print("Aferin, köyünü kurtardın!\n")
        cevap = input("Çok yorulmadıysan bir el daha oynamak ister misin? -Evet\n -Hayır\n")

        if cevap == "Hayır":
          print("Ben de oynamak istemiyordum zaten, iyi oyundu, görüşürüz!")
          break
        elif cevap == "Evet":
          value1 -= 2
          print("Harika ben de bir oyun daha oynamak isterim.")
          continue
        else:
          print("Lütfen geçerli bir değer giriniz!")
          continue

      if value2 == 2 and value1 == 1:
        print("Ben kazandım hahaha!")
        cevap = input("Çok yorulmadıysan bir el daha oynamak ister misin? -Evet\n -Hayır\n")

        if cevap == "Hayır":
          print("Ben de oynamak istemiyordum zaten, iyi oyundu, görüşürüz!")
          break
        elif cevap == "Evet":
          value1 == -1
          value2 == -2
          print("Harika ben de bir oyun daha oynamak isterim.")
          continue
        else:
          print("Lütfen geçerli bir değer giriniz!")
          continue

      if value2 == 2 and value1 == 0 :
        print("Ben kazandım hahaha!")
        cevap = input("Çok yorulmadıysan bir el daha oynamak ister misin? -Evet\n -Hayır\n")

        if cevap == "Hayır":
          print("Ben de oynamak istemiyordum zaten, iyi oyundu, görüşürüz!")
          break
        elif cevap == "Evet":
          value2 == -2
          print("Harika ben de bir oyun daha oynamak isterim.")
          continue
        else:
          print("Lütfen geçerli bir değer giriniz!")
          continue

# %%
Vampir_Büyücü_Avcı()
